# %%
# Technicalities

import sys, os

src = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
src = os.path.abspath(os.path.join(src, os.pardir))
sys.path.append(src)

# %% [markdown]
# # Notebook: Explore dataset

# %%
from prc_challenge.data import EmployeeSalary

supervised_dataset = EmployeeSalary()

# %%
supervised_dataset.train_X.head()
# Out:
#      gender department                          department_name  \
# 1042      M        HHS  Department of Health and Human Services
# 4260      M        FRS                 Fire and Rescue Services
# 6495      M        DOT             Department of Transportation
# 3407      F        LIB           Department of Public Libraries
# 6151      M        CAT                 County Attorney's Office
#
#                           division assignment_category  \
# 1042    Positive Youth Development    Fulltime-Regular
# 4260                      Training    Fulltime-Regular
# 6495              Highway Services    Fulltime-Regular
# 3407         Silver Spring Library    Parttime-Regular
# 6151  Insurance Defense Litigation    Fulltime-Regular
#
#             employee_position_title date_first_hired  year_first_hired
# 1042    Community Services Aide III       06/25/2007              2007
# 4260    Fire/Rescue Assistant Chief       09/20/1993              1993
# 6495           Equipment Operator I       07/27/2015              2015
# 3407                    Librarian I       12/05/2014              2014
# 6151  Assistant County Attorney III       06/17/2001              2001

# %%
supervised_dataset.train_Y.head()
# Out:
# 1042     57244.34
# 4260    144472.55
# 6495     38020.38
# 3407     25703.77
# 6151    140794.00
# Name: current_annual_salary, dtype: float64
