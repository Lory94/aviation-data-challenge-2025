# %%
# Technicalities

import sys, os

src = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
src = os.path.abspath(os.path.join(src, os.pardir))
sys.path.append(src)

# %% [markdown]
# # Leaderboard

# %%
from prc_challenge.utils import show_leaderboard

show_leaderboard()
# Out:
# /home/npo/projects/prc2025/repo/prc-challenge-2025
# Accordion(children=(HTML(value='<pre>Timestamp: 20251110-16:15:57\nSeed: 1\nConfig:\n{\n  "cleaning": [],\n  "…
